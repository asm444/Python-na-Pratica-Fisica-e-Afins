# %% [markdown]
# Células do tipo "texto" podem ser criadas no botão *+ TEXT* , enquanto as do tipo "código" podem ser criadas com no botão *+ CODE* abaixo da célula.

# %% [markdown]
# Abaixo, vemos como fazer um título. Basta digitar # no começo de uma célula para um título e ## para subtítulo.

# %% [markdown]
# # Comandos básicos do Jupyter Notebook

# %% [markdown]
# 1. Usamos # para anotar no Jupyter Notebook;
#
# 2. alt+enter cria uma nova célula do tipo código;
#
# 3. ctrl+enter compila a célula do tipo código;

# %%
# está é a célula criada com o alt+enter na célula acima
# a anotação acima foi feita usando "#"
# a anotação de cima também
# e essa também

# %% [markdown]
# # Operações básicas

# %%
2+3 # soma, compilamos com ctrl+enter
# Out:
# 5

# %%
8-7 # subtração, compilamos com ctrl+enter
# Out:
# 1

# %%
2*5 # produto
# Out:
# 10

# %%
9/3 # divisão
# Out:
# 3.0

# %%
7**2 # potenciação, é a mais diferente!
# Out:
# 49

# %% [markdown]
# Obviamente, essas contas podem ser todas feitas no braço. O legal da programação é fazer contas grandes, por exemplo:

# %%
29380721893721893213798 + 87324623874632874634
# Out:
# 29468046517596526088432

# %%
98687578567845764 - 89765384795628937424623894632
# Out:
# -89765384795530249846056048868

# %%
329847324783264873292345327843254 * 98324723904862384962348903264
# Out:
# 32432147140071990678935500181041016586254843853846009400981056

# %%
8757648365 / 987967986789
# Out:
# 0.00886430378525045

# %%
239**283 # esse vai ficar enorme!
# Out:
# ...

# %% [markdown]
# # Tipos de variáveis
#
# Variáveis são nomes que damos pra alguma informação, como por exemplo, quando dizemos
#
# $$ x = 2 $$
#
# estamos declarando uma variável. Elas vêm em vários tipos diferentes, e cada um carrega um tipo de informação diferente. Vamos agora ver um pouco sobre os tipos de variáveis mais comuns.

# %% [markdown]
# ## 1. str - string
#
# Variáveis do tipo string carregam informações como palavras ou textos. Por exemplo:

# %%
nome = 'luiz' # declarar com aspas!
nome          # ao escrever a variável na última linha da célula, ela aparece na tela
# Out:
# 'luiz'

# %% [markdown]
# Também podemos fazer ela aparecer na tela usando o comando print(**VARIÁVEL**) . Por exemplo:

# %%
sobrenome = 'demétrio'
print(sobrenome)
# Out:
# demétrio

# %% [markdown]
# Note que

# %%
nome
sobrenome
# Out:
# 'demétrio'

# %% [markdown]
# é diferente de

# %%
print(nome)
print(sobrenome)
# Out:
# luiz
# demétrio

# %% [markdown]
# Com o primeiro caso printando apenas a última variável, e o outro sendo útil quando temos mais de uma variável.

# %% [markdown]
# ## 2. int - inteiro
#
# Variáveis do tipo inteiro carregam números inteiros. Por exemplo:

# %%
idade = 23
print(idade)
# Out:
# 23

# %% [markdown]
# Agora que temos dois tipos diferentes de variáveis, é útil termos algum jeito de compará-las. Uma forma de fazer isso é usando o comando type(**VARIÁVEL**). Vejamos alguns exemplos:

# %%
type(nome)
# Out:
# str

# %%
print(type(nome))
print(type(idade))
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# Ao analisarmos programas de outras pessoas, é útil usar esse comando para verificar os tipos de variáveis desconhecidas. Obviamente, nesse caso poderia-se ver facilmente que os tipos eram diferentes. Porém, veremos agora um outro tipo de variável em que a diferença é menos trivial.

# %% [markdown]
# ## 3. float - número real
#
# Variáveis do tipo float representam números reais. O termo "número de ponteiro flutuante" é usado devido à posição da vírgula importar nesse tipo de número:
#
# $$ 3,42 \neq 34,2 \, .$$
#
# Vejamos agora alguns exemplos.

# %%
altura = 1.82 # o Python segue o jeito americano de escrever números, usando pontos ao invés de vírgulas
print(altura)
print(type(altura))
# Out:
# 1.82
# <class 'float'>

# %% [markdown]
# Note que esse tipo é diferente do int, sendo útil ter o comando type( ) para diferenciá-los.

# %% [markdown]
# # Operações com variáveis

# %% [markdown]
# Veremos agora como operar com variáveis, o que facilita muito a escrita de códigos.

# %%
a = 2 
b = 3 # acabamos de declarar nossas variáveis

print(a+b) # soma
print(a-b) # subtração
print(a*b) # multiplicação com *
print(a/b) # divisão
print(a**b) # potenciação
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 8

# %% [markdown]
# Note que podemos definir novas variáveis com base nelas:

# %%
soma = a+b 
subtração = a-b 
produto = a*b
divisão = a/b
potenciação = a**b

# %%
print(soma)
print(subtração)
print(produto)
print(divisão)
print(potenciação)
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 8

# %% [markdown]
# Note que, ao printarmos os tipos dessas variáveis, obtemos:

# %%
print(type(soma))
print(type(subtração))
print(type(produto))
print(type(divisão))
print(type(potenciação))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# Veja que o tipo mudou de int para float ao fazermos a divisão, porque a divisão de dois naturais nem sempre é um natural.

# %% [markdown]
# E, é claro, sempre podemos fazer a mesma coisa para números absurdamente grandes:

# %%
c = 8758757684567847864675876566785
d = 3478689686775764674657456565676

print(c+d)
print(c-d)
print(c*d)
print(c/d)
# Out:
# 12237447371343612539333333132461
# 5280067997792083190018420001109
# 30469000026274148539637369622390198141326456555573351752671660
# 2.517832423473774

# %% [markdown]
# # 4. list - listas

# %% [markdown]
# Variáveis do tipo list são listas. Esse é fácil de lembrar!

# %%
numeros = [1,2,3] # definimos listas usando colchetes
print(numeros)
print(type(numeros))
# Out:
# [1, 2, 3]
# <class 'list'>

# %% [markdown]
# Também podemos criar listas usando variáveis antigas:

# %%
dados = [nome,idade,altura]
print(dados)
# Out:
# ['luiz', 23, 1.82]

# %% [markdown]
# Além disso, as listas tem mais propriedades que os outros tipos de variáveis que vimos. Por exemplo, podemos identificar elementos das listas:

# %%
print(dados[0]) # começamos a contar do zero
print(dados[1])
print(dados[2])
# Out:
# luiz
# 23
# 1.82

# %% [markdown]
# Também temos dois comandos importantíssimos para listas:
#
# 1. len(**LISTA**) - fornece o tamanho da lista;
# 2. **LISTA**.append(**QUALQUERCOISA**) - adiciona **QUALQUERCOISA** à lista;
#
# Vejamos isso na prática:

# %%
print(len(dados)) # tamanho da lista dados
# Out:
# 3

# %%
dados.append('masculino') # adicionamos mais uma informação à lista dados, que é o gênero
print(dados)
# Out:
# ['luiz', 23, 1.82, 'masculino']

# %% [markdown]
# Podemos ainda definir listas vazias, cuja importância ficará clara mais para frente:

# %%
vazia = []
print(vazia)
# Out:
# []
